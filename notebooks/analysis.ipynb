# %% [markdown]
# # Analysis logs

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import json

path = '../resources'
datapath = os.path.join(path, 'data')
paramspath = os.path.join(path, 'params')
imagepath = os.path.join(path, 'plots')
file = '2_custom_reward_train'

# %%
def plot(path, filename):
    filetext = os.path.join(os.path.join(path, 'data'), filename + '.txt')
    fileplot = os.path.join(os.path.join(path, 'plots'), filename + '.png')
    data = np.loadtxt(filetext)
    
    fig = plt.figure(figsize=(12,6))
    plt.plot(data[:,0], data[:,1])
    plt.xlabel('episodio', fontsize=12)
    plt.ylabel('número de pasos de tiempo', fontsize=12)
    plt.savefig(fileplot, dpi=500)

# %%
def read_params(path, filename):
    fileparams = os.path.join(os.path.join(path, 'params'), filename + '.json')
    with open(fileparams) as json_file:  
        data = json.load(json_file)
    return data

# %% [markdown]
# ## Train

# %% [markdown]
# ### 1 custom

# %%
filename = '1_custom_reward_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0002,
#  'critic_lr': 0.002,
#  'batch_size': 64,
#  'buffer_size': 1000000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 500,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 0.3,
#  'init_episode': 174,
#  'file': '1_custom_reward',
#  'resources': 'resources'}

# %% [markdown]
# ### 2 custom

# %%
filename = '2_custom_reward_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0001,
#  'critic_lr': 0.001,
#  'batch_size': 64,
#  'buffer_size': 1000000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 500,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 0.3,
#  'init_episode': 0,
#  'file': '2_custom_reward',
#  'resources': 'resources'}

# %% [markdown]
# ### 0

# %%
filename = '0_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0002,
#  'critic_lr': 0.002,
#  'batch_size': 64,
#  'buffer_size': 1000000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 2000,
#  'max_steps': 10000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 0.6,
#  'init_episode': 0,
#  'file': '0'}

# %% [markdown]
# ### 1

# %%
filename = '1_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0002,
#  'critic_lr': 0.002,
#  'batch_size': 64,
#  'buffer_size': 1000000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 500,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '1',
#  'resources': 'resources'}

# %% [markdown]
# ### 2

# %%
filename = '2_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0002,
#  'critic_lr': 0.002,
#  'batch_size': 64,
#  'buffer_size': 300000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 500,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '2',
#  'resources': 'resources'}

# %% [markdown]
# ### 3

# %%
filename = '3_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0001,
#  'critic_lr': 0.001,
#  'batch_size': 64,
#  'buffer_size': 300000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 500,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '3',
#  'resources': 'resources'}

# %% [markdown]
# ### 4 before
#
# Up to 2000 N iterations to update target network params.
#
# Change buffer size to 20000.

# %%
plot(path, '4_before_train')
read_params(path, '4_train')
# Out:
# {'actor_lr': 0.0001,
#  'critic_lr': 0.001,
#  'batch_size': 64,
#  'buffer_size': 20000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '4',
#  'resources': 'resources'}

# %% [markdown]
# ### 4
#
# Update to 500 iterations for update target network params.
#
# Load params for target networks from disk file model.

# %%
filename = '4_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0001,
#  'critic_lr': 0.001,
#  'batch_size': 64,
#  'buffer_size': 20000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '4',
#  'resources': 'resources'}

# %% [markdown]
# ### 5
#
# Update to 500 iterations for update target network params.
#
# Load params for target networks from disk file model.

# %%
filename = '5_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 3e-05,
#  'critic_lr': 0.0007,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '5',
#  'resources': 'resources'}

# %%
filename = '6_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 3e-05,
#  'critic_lr': 0.0007,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '6',
#  'resources': 'resources'}

# %%
filename = '7_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 3e-05,
#  'critic_lr': 0.0007,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '7',
#  'resources': 'resources'}

# %%
filename = '8_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 3e-05,
#  'critic_lr': 0.0007,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '8',
#  'resources': './resources'}

# %%
filename = '9_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 3e-05,
#  'critic_lr': 0.0007,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 0,
#  'file': '9',
#  'resources': './resources',
#  'tensorboard': 1}

# %%
filename = '10_custom_f_reward_train'

plot(path, filename)
read_params(path, filename)
# Out:
# {'actor_lr': 0.0001,
#  'critic_lr': 0.001,
#  'batch_size': 64,
#  'buffer_size': 10000,
#  'gamma': 0.99,
#  'tau': 0.001,
#  'seed': 777,
#  'max_episodes': 1000,
#  'max_steps': 2000,
#  'state_size': 29,
#  'action_size': 3,
#  'epsilon_rate': 1,
#  'init_episode': 119,
#  'file': '10_custom_f_reward',
#  'resources': './resources',
#  'tensorboard': 1}

# %% [markdown]
# ## Test

# %%
filename = '5_test'

plot(path, filename)
#read_params(path, filename)

# %%
filename = '6_test'

plot(path, filename)
#read_params(path, filename)

# %%
filename = '7_test'

plot(path, filename)
#read_params(path, filename)
